                 'GBPJPY':0.001,'USDJPY':0.001,'EURCAD':0.001,'USDCNH':0.00001,'GBPNZD':0.00001,'AUDUSD':0.00001,
                'USDMXN':0.00001,'CADCHF':0.00001,'CADJPY':0.001,'USDNOK':0.00001,'USDSGD':0.00001,'USDPLN':0.00001,
                'USDTRY':0.00001,'EURJPY':0.001,'EURMXN':0.00001,'NZDUSD':0.00001,'GBPCHF':0.00001,'AUDCHF':0.00001,
                'GBPAUD':0.00001}
    return (round(1/diccionario[ticker]))

# %%
def f_columnas_pips(data):
    pip = pd.DataFrame(0, index=range(len(data)),columns=['pips'])
    pip['instrument']=data['Symbol']
    for i in range(len(data)):
        if data.loc[i,'Type']=='sell':
            pip.loc[i,'pips']=(data.iloc[i,5]-data.iloc[i,9])*f_pip_size(pip.loc[i,'instrument'])
        else:
            pip.loc[i,'pips']=(data.iloc[i,9]-data.iloc[i,5])*f_pip_size(pip.loc[i,'instrument'])
    pip['pips_acm']=pip['pips'].cumsum()
    pip['profit_acm']=data['Profit'].astype(float).cumsum()
    return pip

# %%
f_columnas_pips(mtf).head()
# Out:
#      pips instrument  pips_acm  profit_acm
# 0  -326.0     USDCAD    -326.0     -122.74
# 1 -1843.0     EURUSD   -2169.0    -1965.74
# 2  -133.0     EURGBP   -2302.0    -2041.72
# 3   -48.0     GBPUSD   -2350.0    -2521.72
# 4   -56.0     GBPUSD   -2406.0    -2577.72

# %%
f_columnas_pips(mtm).head()
# Out:
#       pips instrument  pips_acm  profit_acm
# 0    457.0     USDJPY     457.0       15.94
# 1     55.0     USDCHF     512.0       18.79
# 2   -183.0     USDCNH     329.0      -46.52
# 3 -10026.0     USDMXN   -9697.0    -2559.64
# 4    469.0     USDJPY   -9228.0     -923.75

# %%
f_columnas_pips(mtp).head()
# Out:
#     pips instrument      pips_acm  profit_acm
# 0  103.0     EURUSD  1.030000e+02       10.30
# 1 -103.0     USDJPY -1.109868e-11        3.13
# 2  100.0     GBPUSD  1.000000e+02        5.13
# 3  102.0     USDCAD  2.020000e+02       12.79
# 4   40.0     EURGBP  2.420000e+02       58.33

# %%
f_columnas_pips(mta).head()
# Out:
#      pips instrument  pips_acm  profit_acm
# 0 -1516.0     GBPUSD   -1516.0    -1516.00
# 1   -88.0     EURGBP   -1604.0    -1613.01
# 2  -581.0     AUDUSD   -2185.0    -2194.01
# 3     2.0     EURGBP   -2183.0    -2191.83
# 4    16.0     GBPUSD   -2167.0    -2175.83

# %%
def f_estadisticas_ba(data,datapip,df):
    df_1=pd.DataFrame({'medida':['Ops totales','Ganadoras','Ganadoras_c','Ganadoras_v','Perdedoras','Perdedoras_c',
                             'Perdedoras_v','Mediana (profit)','Mediana (pips)','r_efectividad','r_proporcion',
                             'r_efectividad_c', 'r_efectividad_v'],
                   'valor':np.zeros(13),
                  'descripcion':['Operaciones totales','Operaciones ganadoras','Operaciones ganadoras de compra',
                                'Operaciones ganadoras de venta','Operaciones perdedoras','Operaciones perdedoras de compra',
                                'Operaciones perdedoras de venta','Mediana de profit de operaciones',
                                 'Mediana de pips de operaciones','Ganadoras totales/ Operaciones totales',
                                'Ganadoras totales/ Perdedoras totales','Ganadoras compras/ Operaciones totales',
                                 'Ganadoras ventas/ Operaciones totales']})
    df_1.iloc[0,1]=len(data)
    df_1.iloc[1,1]=len(data[data['Profit']>0])
    df_1.iloc[2,1]=len(data[(data['Profit']>0) & (data['Type']=='buy')])
    df_1.iloc[3,1]=len(data[(data['Profit']>0) & (data['Type']=='sell')])
    df_1.iloc[4,1]=len(data[data['Profit']<0])
    df_1.iloc[5,1]=len(data[(data['Profit']<0) & (data['Type']=='buy')])
    df_1.iloc[6,1]=len(data[(data['Profit']<0) & (data['Type']=='sell')])
    df_1.iloc[7,1]=data['Profit'].median()
    df_1.iloc[8,1]=datapip['pips'].median()
    df_1.iloc[9,1]=df_1.iloc[1,1]/df_1.iloc[0,1]
    df_1.iloc[10,1]=df_1.iloc[1,1]/df_1.iloc[5,1]
    df_1.iloc[11,1]=df_1.iloc[3,1]/df_1.iloc[1,1]
    df_1.iloc[10,1]=df_1.iloc[4,1]/df_1.iloc[1,1]
    df_1['valor']=round(df_1['valor'],2)
    
    uniques=data['Symbol'].unique()
    rank=[]
    for i in uniques:
        rank.append(round(len(data[(data['Profit']>0) & (data['Symbol']==i)])/len(data[data['Symbol']==i])*100,2))
    df_2_ranking=pd.DataFrame({'Symbol':uniques,'rank %':rank})
    
    diccionario={'tabla':df_1,'ranking':df_2_ranking}
    return diccionario[df]

# %%
f_estadisticas_ba(mtf,f_columnas_pips(mtf),'tabla').head()
# Out:
#         medida  valor                      descripcion
# 0  Ops totales   23.0              Operaciones totales
# 1    Ganadoras   10.0            Operaciones ganadoras
# 2  Ganadoras_c    7.0  Operaciones ganadoras de compra
# 3  Ganadoras_v    3.0   Operaciones ganadoras de venta
# 4   Perdedoras   13.0           Operaciones perdedoras

# %%
f_estadisticas_ba(mtf,f_columnas_pips(mtf),'ranking').head()
# Out:
#    Symbol  rank %
# 0  USDCAD   50.00
# 1  EURUSD   66.67
# 2  EURGBP    0.00
# 3  GBPUSD   16.67
# 4  USDJPY  100.00

# %%
f_estadisticas_ba(mtm,f_columnas_pips(mtm),'tabla').head()
# Out:
#         medida  valor                      descripcion
# 0  Ops totales   22.0              Operaciones totales
# 1    Ganadoras   11.0            Operaciones ganadoras
# 2  Ganadoras_c    9.0  Operaciones ganadoras de compra
# 3  Ganadoras_v    2.0   Operaciones ganadoras de venta
# 4   Perdedoras   11.0           Operaciones perdedoras

# %%
f_estadisticas_ba(mtm,f_columnas_pips(mtm),'ranking').head()
# Out:
#    Symbol  rank %
# 0  USDJPY    50.0
# 1  USDCHF    80.0
# 2  USDCNH     0.0
# 3  USDMXN     0.0
# 4  USDNOK    50.0

# %%
f_estadisticas_ba(mtp,f_columnas_pips(mtp),'tabla').head()
# Out:
#         medida  valor                      descripcion
# 0  Ops totales   74.0              Operaciones totales
# 1    Ganadoras   41.0            Operaciones ganadoras
# 2  Ganadoras_c   29.0  Operaciones ganadoras de compra
# 3  Ganadoras_v   12.0   Operaciones ganadoras de venta
# 4   Perdedoras   33.0           Operaciones perdedoras

# %%
f_estadisticas_ba(mtp,f_columnas_pips(mtp),'ranking').head()
# Out:
#    Symbol  rank %
# 0  EURUSD   54.17
# 1  USDJPY   83.33
# 2  GBPUSD   57.14
# 3  USDCAD   60.00
# 4  EURGBP   41.67

# %%
f_estadisticas_ba(mta,f_columnas_pips(mta),'tabla').head()
# Out:
#         medida  valor                      descripcion
# 0  Ops totales   47.0              Operaciones totales
# 1    Ganadoras   27.0            Operaciones ganadoras
# 2  Ganadoras_c   10.0  Operaciones ganadoras de compra
# 3  Ganadoras_v   17.0   Operaciones ganadoras de venta
# 4   Perdedoras   20.0           Operaciones perdedoras

# %%
f_estadisticas_ba(mta,f_columnas_pips(mta),'ranking').head()
# Out:
#    Symbol  rank %
# 0  GBPUSD   62.50
# 1  EURGBP   80.00
# 2  AUDUSD   42.86
# 3  EURUSD   50.00
# 4  GBPJPY  100.00

# %% [markdown]
# # Métricas de Atribución al Desempeño

# %% [markdown]
# 'profit_acm_d': Es la columna de evolución de capital en la cuenta de trading, inicializala con $100,000 Usd y ve sumando (restando) las ganancias (perdidas) de la columna 'profit_acm'. Esta columna sería el valor de un título para tu fondo de inversión, o también la puedes pensar como la evolución del capital en tu cuenta de trading. Esta columna solo se utiliza para el DrawDown, tanto en capital como en Pips.
#
#
# f_evolucion_capital:  Esta es una funcion cuya entrada es tu DataFrame del histórico de operaciones (utilizarás solo las columnas de timestamp y profit por transaccion), la salida de esta función es un DataFrame con 3 columnas:
#
# - la primera columna se debe de nombrar 'timestamp' y contiene las fechas dia a dia durante el priodo que hiciste trading, (Como utilizarás históricos del lab2 entonces es todos los días de la semana, excepto el sábado).
# - La segunda columna es 'profit_d' que es el profit por dia por cada dia de todos los contenidos en el periodo que hiciste trading (es posible que tengas dias con profit 0) y es el profit de todo el día (en caso de haber mas de 1 operación es la suma de todos los profits).
# - La tercera columna de este DataFrame es 'profit_acm_d' que es el profit acumulado diario de tu cuenta de capital.  Particularmente, la columna 'profit_acm_d' representa el capital diario de tu cuenta de trading (aun y que en 1 dia hubieras hecho mas de una operacion o que en un dia no hagas ninguna operacion), este es profit_acm_d  es expresado en  capital (dinero)  y es una cifra numerica sin agregar simbolo de dinero, a esta cifra agrégale el capital inicial, en la cuenta del histórico de ejemplo es (100,000). Con esta columna estás obteniendo lo que sería el equivalente al valor diario de tu portafolio (en este caso de una estrategia de trading en lugar de varias acciones) y con este valor ya tendras una cifra distribuida diariamente que representa el valor de tu capital (o lo que sería equivalente al precio diario de una acción o de un etf).
#
#
# Al mandar llamar la función f_evolucion_capital, cuya entrada es tu dataframe con el historico de operaciones, a la salida deberías de poder obtener un DataFrame como el siguiente (las cifras son de ejemplo):

# %%
k=100000
def f_evolucion_capital(data):
    dates=[]
    for i in range(len(data)):
        data.iloc[i,0]=data.iloc[i,0].strftime('%Y-%m-%d')
        dates.append(data.iloc[i,0])
    dates=list(set(dates))
    dates.sort()
    dateslist=pd.date_range(dates[0],dates[-1],freq='d').strftime('%Y-%m-%d')
    evcap=pd.DataFrame({'timestamp':dateslist})
    for i in range(len(dateslist)):
        evcap.loc[i,'profit_d']=data[data['Time']==dateslist[i]]['Profit'].sum()
    evcap.loc[0,'profit_acm_d']=k+evcap.loc[0,'profit_d']
    for i in range(len(dateslist)-1):
        evcap.loc[i+1,'profit_acm_d']=evcap.loc[i,'profit_acm_d']+evcap.loc[i+1,'profit_d']
    return evcap

# %%
f_evolucion_capital(mtf)
# Out:
#     timestamp  profit_d  profit_acm_d
# 0  2022-09-20  -2837.72      97162.28
# 1  2022-09-21      0.00      97162.28
# 2  2022-09-22     52.66      97214.94
# 3  2022-09-23 -91492.43       5722.51
# 4  2022-09-24      0.00       5722.51
# 5  2022-09-25      0.00       5722.51
# 6  2022-09-26   -247.75       5474.76

# %%
f_evolucion_capital(mtm)
# Out:
#     timestamp  profit_d  profit_acm_d
# 0  2022-09-16    374.51     100374.51
# 1  2022-09-17      0.00     100374.51
# 2  2022-09-18      0.00     100374.51
# 3  2022-09-19  -3445.76      96928.75
# 4  2022-09-20      0.00      96928.75
# 5  2022-09-21   6315.37     103244.12
# 6  2022-09-22     40.46     103284.58

# %%
f_evolucion_capital(mtp)
# Out:
#     timestamp  profit_d  profit_acm_d
# 0  2022-09-19   -161.18      99838.82
# 1  2022-09-20   -672.05      99166.77
# 2  2022-09-21  -7981.96      91184.81
# 3  2022-09-22   -224.13      90960.68
# 4  2022-09-23   1320.12      92280.80
# 5  2022-09-24      0.00      92280.80
# 6  2022-09-25      0.00      92280.80
# 7  2022-09-26  -5549.02      86731.78

# %%
f_evolucion_capital(mta)
# Out:
#     timestamp  profit_d  profit_acm_d
# 0  2022-09-23  -1697.71      98302.29
# 1  2022-09-24      0.00      98302.29
# 2  2022-09-25      0.00      98302.29
# 3  2022-09-26    -47.64      98254.65

# %% [markdown]
# Teniendo este DataFrame podrás calcular las Medidas de Atribución al Desempeño que te describo en el siguiente punto:
#
# f_estadisticas_mad: Una función que regrese un DataFrame  con los resultados de cada MAD expresadas en términos diarios, en renglones,  'sharpe', 'drawdown_capi', 'drawup_capi'.
# Nota: Utilizar de Benchmark precios diarios (cierre de precio ajustado) SP500. Se calculara el promedio
#
# Calcular las siguientes Medidas de Atribución al Desempeño (MAD):
#
# Sharpe Ratio Original:
# rp: Promedio de los rendimientos logarítmicos de profit_acm_d
# rf: 5%
# sdp: Desviación estándar de todos los rendimientos con los que se calculó rp.
# Sharpe Ratio Actualizado:
# r_trader: Promedio de los rendimientos logarítmicos de profit_acm_d
# r_benchmark: Promedio de los rendimientos logarítmicos de Benchmark
# sdp: Desviación estándar de la resta de todos los rendimientos (r_trader - r_benchmark)
# DrawDown (Capital):
# Minusvalia máxima que se registró en la evolución de los valores (de 'profit_acm_d').
# Obtener información de esta métrica como la siguiente:
# "Fecha Inicial", "Fecha Final", "DrawDown $ (capital)".
# DrawUp (Capital):
# Plusvalía máxima que se registró en la evolución de los valores (de 'profit_acm_d').
# Obtener información de esta métrica como la siguiente:
# "Fecha Inicial", "Fecha Final", "DrawUp $ (capital)".
